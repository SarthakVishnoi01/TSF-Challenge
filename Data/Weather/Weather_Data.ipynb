# %%
# Download any package here
# # Install a pip package in the current Jupyter kernel
# import sys
# !{sys.executable} -m pip install pandas

# %%
from wwo_hist import retrieve_hist_data

# %%
# Set the working directory
import os
os.chdir(r"C:\Users\Sarthak Vishnoi\TSF-Challenge\Data\Weather")

# %%
# Intialisations
frequency=24
start_date = '01-JAN-2020'
end_date = '04-APR-2020'
api_key = '016c031d9643406991194842200504'

# %%
# For alphabet A
location_list_A = ['agra','ahmedabad','ahmednagar','aizawl','ajmer','alappuzha','alwar', 'ambala','amritsar','anantapur', 'aurangabad']
hist_weather_data_A = retrieve_hist_data(api_key,
                                location_list_A,
                                start_date,
                                end_date,
                                frequency,
                                location_label = False,
                                export_csv = True,
                                store_df = True)
# Out:
# Retrieving weather data for agra
#
#
# Currently retrieving data for agra: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.418516
# Currently retrieving data for agra: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:02.614571
# Currently retrieving data for agra: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.957549
# Currently retrieving data for agra: from 2020-04-01 to 2020-04-04
# Time elapsed (hh:mm:ss.ms) 0:00:04.856913
#
#
# export agra completed!
#
#
#
#
# Retrieving weather data for ahmedabad
#
#
# Currently retrieving data for ahmedabad: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.318630
# Currently retrieving data for ahmedabad: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:02.587835
# Currently retrieving data for ahmedabad: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:04.161401
# Currently retrieving data for ahmedabad: from 2020-04-01 to 2020-04-04
# ...

# %%
# For alphabet B
location_list_B = ['Bareilly','Begusarai','Bengaluru','Bhadradri+Kothagudem','Bhadrak', 'Bhagalpur','Bhavnagar','Bhilwara', 'Bhopal', 'Bidar', 'Bikaner', 'Bilaspur', 'Buldana']
hist_weather_data_B = retrieve_hist_data(api_key,
                                location_list_B,
                                start_date,
                                end_date,
                                frequency,
                                location_label = False,
                                export_csv = True,
                                store_df = True)
# Out:
# Retrieving weather data for Bareilly
#
#
# Currently retrieving data for Bareilly: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.730759
# Currently retrieving data for Bareilly: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:03.099228
# Currently retrieving data for Bareilly: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:04.969296
# Currently retrieving data for Bareilly: from 2020-04-01 to 2020-04-04
# Time elapsed (hh:mm:ss.ms) 0:00:05.607309
#
#
# export Bareilly completed!
#
#
#
#
# Retrieving weather data for Begusarai
#
#
# Currently retrieving data for Begusarai: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.285307
# Currently retrieving data for Begusarai: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:02.506596
# Currently retrieving data for Begusarai: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.763582
# ...

# %%
# For alphabet C
location_list_C = ['Chandigarh', 'Chengalpattu', 'Chennai', 'Chitradurga', 'Chittoor','Churu','Coimbatore']
hist_weather_data_C = retrieve_hist_data(api_key,
                                location_list_C,
                                start_date,
                                end_date,
                                frequency,
                                location_label = False,
                                export_csv = True,
                                store_df = True)
# Out:
# Retrieving weather data for Chandigarh
#
#
# Currently retrieving data for Chandigarh: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.591706
# Currently retrieving data for Chandigarh: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:02.998910
# Currently retrieving data for Chandigarh: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:04.608575
# Currently retrieving data for Chandigarh: from 2020-04-01 to 2020-04-04
# Time elapsed (hh:mm:ss.ms) 0:00:05.469401
#
#
# export Chandigarh completed!
#
#
#
#
# Retrieving weather data for Chengalpattu
#
#
# Currently retrieving data for Chengalpattu: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.700314
# Currently retrieving data for Chengalpattu: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:03.528371
# Currently retrieving data for Chengalpattu: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:05.073172
# ...

# %%
# For alphabet D
location_list_D = ['Dakshina+Kannada', 'Dehradun', 'Dharwad', 'Dindigul', 'Dungarpur']
hist_weather_data_D = retrieve_hist_data(api_key,
                                location_list_D,
                                start_date,
                                end_date,
                                frequency,
                                location_label = False,
                                export_csv = True,
                                store_df = True)
# Out:
# Retrieving weather data for Dakshina+Kannada
#
#
# Currently retrieving data for Dakshina+Kannada: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.499401
# Currently retrieving data for Dakshina+Kannada: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:03.118428
# Currently retrieving data for Dakshina+Kannada: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:04.694866
# Currently retrieving data for Dakshina+Kannada: from 2020-04-01 to 2020-04-04
# Time elapsed (hh:mm:ss.ms) 0:00:05.438454
#
#
# export Dakshina+Kannada completed!
#
#
#
#
# Retrieving weather data for Dehradun
#
#
# Currently retrieving data for Dehradun: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.000418
# Currently retrieving data for Dehradun: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:03.896109
# Currently retrieving data for Dehradun: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:05.959834
# ...

# %%
# For alphabet E
location_list_E = ['East+Delhi', 'East+Godavari', 'Ernakulam', 'Erode']
hist_weather_data_E = retrieve_hist_data(api_key,
                                location_list_E,
                                start_date,
                                end_date,
                                frequency,
                                location_label = False,
                                export_csv = True,
                                store_df = True)
# Out:
# Retrieving weather data for East+Delhi
#
#
# Currently retrieving data for East+Delhi: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.695014
# Currently retrieving data for East+Delhi: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:03.206817
# Currently retrieving data for East+Delhi: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:04.572217
# Currently retrieving data for East+Delhi: from 2020-04-01 to 2020-04-04
# Time elapsed (hh:mm:ss.ms) 0:00:05.429531
#
#
# export East+Delhi completed!
#
#
#
#
# Retrieving weather data for East+Godavari
#
#
# Currently retrieving data for East+Godavari: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.572325
# Currently retrieving data for East+Godavari: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:03.188589
# Currently retrieving data for East+Godavari: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:04.480381
# ...

# %%
# For alphabet F
location_list_A = ['Faridabad']
hist_weather_data_A = retrieve_hist_data(api_key,
                                location_list_A,
                                start_date,
                                end_date,
                                frequency,
                                location_label = False,
                                export_csv = True,
                                store_df = True)
# Out:
# Retrieving weather data for Faridabad
#
#
# Currently retrieving data for Faridabad: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.561831
# Currently retrieving data for Faridabad: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:02.959930
# Currently retrieving data for Faridabad: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:04.883266
# Currently retrieving data for Faridabad: from 2020-04-01 to 2020-04-04
# Time elapsed (hh:mm:ss.ms) 0:00:05.472483
#
#
# export Faridabad completed!

# %%
# For alphabet G
location_list_A = ['Gandhinagar','Gautam+Buddh+Nagar','Gaya', 'Ghaziabad', 'Gir', 'Goalpara', 'Gondia', 'Gopalganj', 'Guntur', 'Gurgaon', 'Gwalior']
hist_weather_data_A = retrieve_hist_data(api_key,
                                location_list_A,
                                start_date,
                                end_date,
                                frequency,
                                location_label = False,
                                export_csv = True,
                                store_df = True)
# Out:
# Retrieving weather data for Gandhinagar
#
#
# Currently retrieving data for Gandhinagar: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:05.684170
# Currently retrieving data for Gandhinagar: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:07.647071
# Currently retrieving data for Gandhinagar: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:11.409484
# Currently retrieving data for Gandhinagar: from 2020-04-01 to 2020-04-04
# Time elapsed (hh:mm:ss.ms) 0:00:12.788332
#
#
# export Gandhinagar completed!
#
#
#
#
# Retrieving weather data for Gautam+Buddh+Nagar
#
#
# Currently retrieving data for Gautam+Buddh+Nagar: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.054689
# Currently retrieving data for Gautam+Buddh+Nagar: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:04.678959
# Currently retrieving data for Gautam+Buddh+Nagar: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:12.766805
# ...

# %%
# For alphabet H
location_list_H = ['Hazaribagh', 'Hisar', 'Hooghly', 'Hoshiarpur', 'Howrah', 'Hyderabad']
hist_weather_data_H = retrieve_hist_data(api_key,
                                location_list_H,
                                start_date,
                                end_date,
                                frequency,
                                location_label = False,
                                export_csv = True,
                                store_df = True)
# Out:
# Retrieving weather data for Hazaribagh
#
#
# Currently retrieving data for Hazaribagh: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:05.141017
# Currently retrieving data for Hazaribagh: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:09.629106
# Currently retrieving data for Hazaribagh: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:12.512204
# Currently retrieving data for Hazaribagh: from 2020-04-01 to 2020-04-04
# Time elapsed (hh:mm:ss.ms) 0:00:14.072417
#
#
# export Hazaribagh completed!
#
#
#
#
# Retrieving weather data for Hisar
#
#
# Currently retrieving data for Hisar: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.878693
# Currently retrieving data for Hisar: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:07.948849
# Currently retrieving data for Hisar: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:11.315426
# ...

# %%
# For alphabet I
location_list_I = ['Idukki', 'Imphal', 'Indore']
hist_weather_data_I = retrieve_hist_data(api_key,
                                location_list_I,
                                start_date,
                                end_date,
                                frequency,
                                location_label = False,
                                export_csv = True,
                                store_df = True)
# Out:
# Retrieving weather data for Idukki
#
#
# Currently retrieving data for Idukki: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.561321
# Currently retrieving data for Idukki: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:06.673612
# Currently retrieving data for Idukki: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:10.452918
# Currently retrieving data for Idukki: from 2020-04-01 to 2020-04-04
# Time elapsed (hh:mm:ss.ms) 0:00:13.284109
#
#
# export Idukki completed!
#
#
#
#
# Retrieving weather data for Imphal
#
#
# Currently retrieving data for Imphal: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.969185
# Currently retrieving data for Imphal: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:05.901718
# Currently retrieving data for Imphal: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:09.104825
# Currently retrieving data for Imphal: from 2020-04-01 to 2020-04-04
# ...

# %%
# For alphabet J
location_list_J = ['Jabalpur', 'Jaipur', 'Jalandhar', 'Jalgaon', 'Jammu', 'Jaunpur', 'Jhunjhunu', 'Jodhpur', 'Jorhat']
hist_weather_data_J = retrieve_hist_data(api_key,
                                location_list_J,
                                start_date,
                                end_date,
                                frequency,
                                location_label = False,
                                export_csv = True,
                                store_df = True)
# Out:
# Retrieving weather data for Jabalpur
#
#
# Currently retrieving data for Jabalpur: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:07.272498
# Currently retrieving data for Jabalpur: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:11.140898
# Currently retrieving data for Jabalpur: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:15.910798
# Currently retrieving data for Jabalpur: from 2020-04-01 to 2020-04-04
# Time elapsed (hh:mm:ss.ms) 0:00:18.864246
#
#
# export Jabalpur completed!
#
#
#
#
# Retrieving weather data for Jaipur
#
#
# Currently retrieving data for Jaipur: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:04.478725
# Currently retrieving data for Jaipur: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:10.568327
# Currently retrieving data for Jaipur: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:13.084239
# ...

# %%
# For alphabet K
# location_list_K = ['Kutch', 'Kadapa', 'Kalaburagi', 'Kalimpong', 'Kamrup', 'Kanchipuram', 'Kangra', 'Kanyakumari', 'Kannur', 'Kanpur', 'Kargil', 'Karimnagar', 'Karur', 'Kasaragod', 'Khordha', 'Kodagu', 'Kolhapur', 'Kolkata', 'Kollam', 'Kottayam', 'Kozhikode', 'Krishna', 'Kurnool']

location_list_K = ['Kanchipuram', 'Kangra', 'Kanyakumari', 'Kannur', 'Kanpur', 'Kargil', 'Karimnagar', 'Karur', 'Kasaragod', 'Khordha', 'Kodagu', 'Kolhapur', 'Kolkata', 'Kollam', 'Kottayam', 'Kozhikode', 'Krishna', 'Kurnool']
hist_weather_data_K = retrieve_hist_data(api_key,
                                location_list_K,
                                start_date,
                                end_date,
                                frequency,
                                location_label = False,
                                export_csv = True,
                                store_df = True)
# Out:
# Retrieving weather data for Kanchipuram
#
#
# Currently retrieving data for Kanchipuram: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:04.213677
# Currently retrieving data for Kanchipuram: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:07.081803
# Currently retrieving data for Kanchipuram: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:10.816398
# Currently retrieving data for Kanchipuram: from 2020-04-01 to 2020-04-04
# Time elapsed (hh:mm:ss.ms) 0:00:15.988987
#
#
# export Kanchipuram completed!
#
#
#
#
# Retrieving weather data for Kangra
#
#
# Currently retrieving data for Kangra: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.531527
# Currently retrieving data for Kangra: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:03.765291
# Currently retrieving data for Kangra: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:07.159332
# ...

# %%
# For alphabet L
location_list_L = ['Lakhisarai', 'Leh', 'Lohit', 'Lucknow', 'Ludhiana']
hist_weather_data_L = retrieve_hist_data(api_key,
                                location_list_L,
                                start_date,
                                end_date,
                                frequency,
                                location_label = False,
                                export_csv = True,
                                store_df = True)
# Out:
# Retrieving weather data for Lakhisarai
#
#
# Currently retrieving data for Lakhisarai: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.436053
# Currently retrieving data for Lakhisarai: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:03.129074
# Currently retrieving data for Lakhisarai: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:04.584525
# Currently retrieving data for Lakhisarai: from 2020-04-01 to 2020-04-04
# Time elapsed (hh:mm:ss.ms) 0:00:05.341219
#
#
# export Lakhisarai completed!
#
#
#
#
# Retrieving weather data for Leh
#
#
# Currently retrieving data for Leh: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.812127
# Currently retrieving data for Leh: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:03.497182
# Currently retrieving data for Leh: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:05.082876
# Currently retrieving data for Leh: from 2020-04-01 to 2020-04-04
# ...

# %%
# For alphabet M
location_list_M = ['Madurai', 'Mahe', 'Mehsana', 'Malappuram', 'Medchal', 'Midnapore', 'Meerut', 'Moradabad', 'Morena', 'Mumbai', 'Mumbai+Suburban', 'Munger', 'Mysuru']
hist_weather_data_M = retrieve_hist_data(api_key,
                                location_list_M,
                                start_date,
                                end_date,
                                frequency,
                                location_label = False,
                                export_csv = True,
                                store_df = True)
# Out:
# Retrieving weather data for Madurai
#
#
# Currently retrieving data for Madurai: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.601005
# Currently retrieving data for Madurai: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:03.242343
# Currently retrieving data for Madurai: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:04.745150
# Currently retrieving data for Madurai: from 2020-04-01 to 2020-04-04
# Time elapsed (hh:mm:ss.ms) 0:00:05.572126
#
#
# export Madurai completed!
#
#
#
#
# Retrieving weather data for Mahe
#
#
# Currently retrieving data for Mahe: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.737581
# Currently retrieving data for Mahe: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:04.872610
# Currently retrieving data for Mahe: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:06.831264
# Currently retrieving data for Mahe: from 2020-04-01 to 2020-04-04
# ...

# %%
# For alphabet N
#North 24 Parganas -> Barasat
#North and Middle Andaman -> Mayabunder
# location_list_N = ['Nadia', 'Nagpur', 'Nalanda', 'Namakkal', 'Nashik', 'New+Delhi', 'Barasat', 'Mayabunder', 'North+Delhi', 'North+East+Delhi', 'North+Goa', 'North+West+Goa']

location_list_N = ['North+Delhi', 'North+East+Delhi', 'North+Goa', 'North+West+Goa']
hist_weather_data_N = retrieve_hist_data(api_key,
                                location_list_N,
                                start_date,
                                end_date,
                                frequency,
                                location_label = False,
                                export_csv = True,
                                store_df = True)
# Out:
# Retrieving weather data for North+Delhi
#
#
# Currently retrieving data for North+Delhi: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.804185
# Currently retrieving data for North+Delhi: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:03.334412
# Currently retrieving data for North+Delhi: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:05.025226
# Currently retrieving data for North+Delhi: from 2020-04-01 to 2020-04-04
# Time elapsed (hh:mm:ss.ms) 0:00:05.597647
#
#
# export North+Delhi completed!
#
#
#
#
# Retrieving weather data for North+East+Delhi
#
#
# Currently retrieving data for North+East+Delhi: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.220237
# Currently retrieving data for North+East+Delhi: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:02.525522
# Currently retrieving data for North+East+Delhi: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.885642
# ...

# %%
# For alphabet P
#Panch Mahal -> Godhra
# location_list_P = ['Palakkad', 'Palwal', 'Godhra', 'Panchkula', 'Panipat', 'Pathanamthitta', 'Patna', 'Pauri', 'Pilibhit', 'Porbandar', 'Prakasam', 'Pratapgarh', 'Puducherry', 'Pune']

location_list_P = ['Pratapgarh', 'Puducherry', 'Pune']
hist_weather_data_P = retrieve_hist_data(api_key,
                                location_list_P,
                                start_date,
                                end_date,
                                frequency,
                                location_label = False,
                                export_csv = True,
                                store_df = True)
# Out:
# Retrieving weather data for Pratapgarh
#
#
# Currently retrieving data for Pratapgarh: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.153580
# Currently retrieving data for Pratapgarh: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:03.568336
# Currently retrieving data for Pratapgarh: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:07.214836
# Currently retrieving data for Pratapgarh: from 2020-04-01 to 2020-04-04
# Time elapsed (hh:mm:ss.ms) 0:00:08.562577
#
#
# export Pratapgarh completed!
#
#
#
#
# Retrieving weather data for Puducherry
#
#
# Currently retrieving data for Puducherry: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.098396
# Currently retrieving data for Puducherry: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:07.898860
# Currently retrieving data for Puducherry: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:16.029270
# ...

# %%
# For alphabet R
#Ranga Reddy -> Shamsabad
# location_list_R = ['Raipur', 'Rajkot', 'Rajouri', 'Ramnathpuram', 'Ranchi', 'Shamshabad', 'Ranipet', 'Rohtak']

location_list_R = ['Ranchi', 'Shamshabad', 'Ranipet', 'Rohtak']
hist_weather_data_R = retrieve_hist_data(api_key,
                                location_list_R,
                                start_date,
                                end_date,
                                frequency,
                                location_label = False,
                                export_csv = True,
                                store_df = True)
# Out:
# Retrieving weather data for Ranchi
#
#
# Currently retrieving data for Ranchi: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.776582
# Currently retrieving data for Ranchi: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:02.998161
# Currently retrieving data for Ranchi: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:04.295236
# Currently retrieving data for Ranchi: from 2020-04-01 to 2020-04-04
# Time elapsed (hh:mm:ss.ms) 0:00:04.973375
#
#
# export Ranchi completed!
#
#
#
#
# Retrieving weather data for Shamshabad
#
#
# Currently retrieving data for Shamshabad: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.798161
# Currently retrieving data for Shamshabad: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:03.908888
# Currently retrieving data for Shamshabad: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:05.947326
# ...

# %%
# For alphabet S
#SAS Nagar -> Mohali
#SPS Nellore -> Nellore
#Shaheed Bhagat Singh Nagar -> Banga
#Shaheed Bhagat Singh Nagar -> Nawanshahr
#South 24 Parganas -> Alipore
#South Andaman -> Port Blair
location_list_S = ['Mohali', 'Nellore', 'Salem', 'Sangli', 'Banga', 'Nawanshahr', 'Shivpuri', 'Sirsa', 'Sivaganga', 'Siwan', 'Sonipat', 'Alipore', 'Port+Blair', 'South+Delhi', 'South+West+Delhi', 'Srinagar', 'Surat']
hist_weather_data_S = retrieve_hist_data(api_key,
                                location_list_S,
                                start_date,
                                end_date,
                                frequency,
                                location_label = False,
                                export_csv = True,
                                store_df = True)
# Out:
# Retrieving weather data for Mohali
#
#
# Currently retrieving data for Mohali: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.447430
# Currently retrieving data for Mohali: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:03.425847
# Currently retrieving data for Mohali: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:04.848140
# Currently retrieving data for Mohali: from 2020-04-01 to 2020-04-04
# Time elapsed (hh:mm:ss.ms) 0:00:06.070221
#
#
# export Mohali completed!
#
#
#
#
# Retrieving weather data for Nellore
#
#
# Currently retrieving data for Nellore: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.888235
# Currently retrieving data for Nellore: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:03.586945
# Currently retrieving data for Nellore: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:05.754495
# Currently retrieving data for Nellore: from 2020-04-01 to 2020-04-04
# ...

# %%
# For alphabet T
# location_list_T = ['Thane', 'Thanjavur', 'Theni', 'Thiruvallur', 'Thiruvananthapuram', 'Thiruvarur', 'Thoothukudi', 'Thrissur', 'Tiruchirappalli', 'Tirunelveli', 'Tiruvannamalai', 'Tonk', 'Tumakuru']

location_list_T = ['Thiruvananthapuram', 'Thiruvarur', 'Thoothukudi', 'Thrissur', 'Tiruchirappalli', 'Tirunelveli', 'Tiruvannamalai', 'Tonk', 'Tumakuru']
hist_weather_data_T = retrieve_hist_data(api_key,
                                location_list_T,
                                start_date,
                                end_date,
                                frequency,
                                location_label = False,
                                export_csv = True,
                                store_df = True)
# Out:
# Retrieving weather data for Thiruvananthapuram
#
#
# Currently retrieving data for Thiruvananthapuram: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.781449
# Currently retrieving data for Thiruvananthapuram: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:04.600609
# Currently retrieving data for Thiruvananthapuram: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:06.480687
# Currently retrieving data for Thiruvananthapuram: from 2020-04-01 to 2020-04-04
# Time elapsed (hh:mm:ss.ms) 0:00:07.069601
#
#
# export Thiruvananthapuram completed!
#
#
#
#
# Retrieving weather data for Thiruvarur
#
#
# Currently retrieving data for Thiruvarur: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.667272
# Currently retrieving data for Thiruvarur: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:03.061522
# Currently retrieving data for Thiruvarur: from 2020-03-01 to 2020-03-31
# ...

# %%
# For alphabet U
# Udham Singh Nagar -> Rudrapur
# Uttara Kannada -> Bhatkal 
location_list_U = ['Rudrapur', 'Udupi', 'Ujjain', 'Una', 'Bhatkal']
hist_weather_data_U = retrieve_hist_data(api_key,
                                location_list_U,
                                start_date,
                                end_date,
                                frequency,
                                location_label = False,
                                export_csv = True,
                                store_df = True)
# Out:
# Retrieving weather data for Rudrapur
#
#
# Currently retrieving data for Rudrapur: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.252145
# Currently retrieving data for Rudrapur: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:03.629178
# Currently retrieving data for Rudrapur: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:05.968539
# Currently retrieving data for Rudrapur: from 2020-04-01 to 2020-04-04
# Time elapsed (hh:mm:ss.ms) 0:00:06.539947
#
#
# export Rudrapur completed!
#
#
#
#
# Retrieving weather data for Udupi
#
#
# Currently retrieving data for Udupi: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.721058
# Currently retrieving data for Udupi: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:02.927675
# Currently retrieving data for Udupi: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:04.257634
# Currently retrieving data for Udupi: from 2020-04-01 to 2020-04-04
# ...

# %%
# For alphabet V 
# Viluppuram is also spelt as Villupuram
# Virudhunagar is also known as Virudupatti
# location_list_V = ['Vadodara', 'Varanasi', 'Vellore', 'Viluppuram', 'Virudhunagar', 'Visakhapatnam']

location_list_V = ['Visakhapatnam']
hist_weather_data_V = retrieve_hist_data(api_key,
                                location_list_V,
                                start_date,
                                end_date,
                                frequency,
                                location_label = False,
                                export_csv = True,
                                store_df = True)
# Out:
# Retrieving weather data for Visakhapatnam
#
#
# Currently retrieving data for Visakhapatnam: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.632316
# Currently retrieving data for Visakhapatnam: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:03.160577
# Currently retrieving data for Visakhapatnam: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:04.546538
# Currently retrieving data for Visakhapatnam: from 2020-04-01 to 2020-04-04
# Time elapsed (hh:mm:ss.ms) 0:00:05.458360
#
#
# export Visakhapatnam completed!

# %%
# For alphabet W 
# location_list_W = ['Wayanad', 'West+Delhi', 'West+Godavari']

location_list_W = ['West+Delhi', 'West+Godavari']
hist_weather_data_W = retrieve_hist_data(api_key,
                                location_list_W,
                                start_date,
                                end_date,
                                frequency,
                                location_label = False,
                                export_csv = True,
                                store_df = True)
# Out:
# Retrieving weather data for West+Delhi
#
#
# Currently retrieving data for West+Delhi: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.035284
# Currently retrieving data for West+Delhi: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:04.830804
# Currently retrieving data for West+Delhi: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:06.450482
# Currently retrieving data for West+Delhi: from 2020-04-01 to 2020-04-04
# Time elapsed (hh:mm:ss.ms) 0:00:07.052860
#
#
# export West+Delhi completed!
#
#
#
#
# Retrieving weather data for West+Godavari
#
#
# Currently retrieving data for West+Godavari: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.705439
# Currently retrieving data for West+Godavari: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:03.523112
# Currently retrieving data for West+Godavari: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:05.293377
# ...

# %%
# For alphabet Y 
#YSR -> Kadapa
location_list_Y = ['Kadapa', 'Yavatmal']
hist_weather_data_Y = retrieve_hist_data(api_key,
                                location_list_Y,
                                start_date,
                                end_date,
                                frequency,
                                location_label = False,
                                export_csv = True,
                                store_df = True)
# Out:
# Retrieving weather data for Kadapa
#
#
# Currently retrieving data for Kadapa: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.158636
# Currently retrieving data for Kadapa: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:04.045589
# Currently retrieving data for Kadapa: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:05.929289
# Currently retrieving data for Kadapa: from 2020-04-01 to 2020-04-04
# Time elapsed (hh:mm:ss.ms) 0:00:06.729806
#
#
# export Kadapa completed!
#
#
#
#
# Retrieving weather data for Yavatmal
#
#
# Currently retrieving data for Yavatmal: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.344490
# Currently retrieving data for Yavatmal: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:03.682912
# Currently retrieving data for Yavatmal: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:05.467138
# Currently retrieving data for Yavatmal: from 2020-04-01 to 2020-04-04
# ...

# %%
#Trying for the citites which are left
# locatoin_list_left=['Bandipore', 'Cachar', 'Chikkaballapur', 'Davanagere', 'Kalaburagi', 'Kalimpong', 'Kamrup', 'Nashik', 'Mayabunder', 'Panchkula', 'Prakasam', 'Ramnathpuram', 'Thiruvallur', 'Virudhnagar', 'Wayanad']
lat_long = ['34.5052,74.6869', '24.7821,92.8577', '13.4355,77.7315', '14.4644,75.9218', '17.3297,76.8343', '27.0594,88.4695', '26.3161,91.5984', '19.9975,73.7898', '12.9131,92.8977', '30.6942,76.8605', '15.3485,79.5603', '9.3639,78.8395', '13.2544,80.0088', '9.5680,77.9624', '11.6854,76.1320']
hist_weather_data_lat_long = retrieve_hist_data(api_key,
                                lat_long,
                                start_date,
                                end_date,
                                frequency,
                                location_label = False,
                                export_csv = True,
                                store_df = True)
# Out:
# Retrieving weather data for 34.5052,74.6869
#
#
# Currently retrieving data for 34.5052,74.6869: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:05.917231
# Currently retrieving data for 34.5052,74.6869: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:07.471657
# Currently retrieving data for 34.5052,74.6869: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:09.791100
# Currently retrieving data for 34.5052,74.6869: from 2020-04-01 to 2020-04-04
# Time elapsed (hh:mm:ss.ms) 0:00:10.366696
#
#
# export 34.5052,74.6869 completed!
#
#
#
#
# Retrieving weather data for 24.7821,92.8577
#
#
# Currently retrieving data for 24.7821,92.8577: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.195844
# Currently retrieving data for 24.7821,92.8577: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:03.094645
# Currently retrieving data for 24.7821,92.8577: from 2020-03-01 to 2020-03-31
# ...
