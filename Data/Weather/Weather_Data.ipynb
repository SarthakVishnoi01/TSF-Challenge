# %%
# Download any package here
# # Install a pip package in the current Jupyter kernel
# import sys
# !{sys.executable} -m pip install pandas

# %%
from wwo_hist import retrieve_hist_data

# %%
# Set the working directory
import os
os.chdir(r"C:\Users\Sarthak Vishnoi\TSF-Challenge\Data\Weather")

# %%
# Intialisations
frequency=24
start_date = '01-JAN-2020'
end_date = '08-APR-2020'
# api_key = '016c031d9643406991194842200504'
# api_key = '764936a7a50e4cb694773340200804'
api_key = '25b608ff66c249a888e104624200804'

# %%
# For alphabet A
location_list_A = ['Adilabad', 'Agra','Ahmedabad','Ahmednagar','Aizawl','Ajmer','Alappuzha','Alwar', 'Ambala', 'Amravati', 'Amritsar','Anantapur', 'Ariyalur', 'Auraiya', 'Aurangabad', 'Azamgarh', 'Alipore']
hist_weather_data_A = retrieve_hist_data(api_key,
                                location_list_A,
                                start_date,
                                end_date,
                                frequency,
                                location_label = False,
                                export_csv = True,
                                store_df = True)
# Out:
# Retrieving weather data for Adilabad
#
#
# Currently retrieving data for Adilabad: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.554934
# Currently retrieving data for Adilabad: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:03.811654
# Currently retrieving data for Adilabad: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:05.114076
# Currently retrieving data for Adilabad: from 2020-04-01 to 2020-04-08
# Time elapsed (hh:mm:ss.ms) 0:00:05.714268
#
#
# export Adilabad completed!
#
#
#
#
# Retrieving weather data for Agra
#
#
# Currently retrieving data for Agra: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.491057
# Currently retrieving data for Agra: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:02.861860
# Currently retrieving data for Agra: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:05.201407
# Currently retrieving data for Agra: from 2020-04-01 to 2020-04-08
# ...

# %%
# For alphabet B
# location_list_B = ['Badgam', 'Bagalkot', 'Baghpat', 'Banda', 'Banswara', 'Bara+Banki', 'Baramula', 'Barasat' 'Bareilly', 'Barnala', 'Barwani', 'Basti', 'Begusarai', 'Belagavi', 'Bellary', 'Bengaluru', 'Bengaluru+Rural', 'Betul', 'Bhadradri+Kothagudem','Bhadrak', 'Bhagalpur', 'Bharatpur', 'Bhavnagar', 'Bhilwara', 'Bhiwani', 'Bhopal', 'Bidar', 'Bijnor', 'Bikaner', 'Bilaspur', 'Bokaro', 'Bulandshahr', 'Buldana']
location_list_B = ['Barasat', 'Bagalkot', 'Bhiwani']
hist_weather_data_B = retrieve_hist_data(api_key,
                                location_list_B,
                                start_date,
                                end_date,
                                frequency,
                                location_label = False,
                                export_csv = True,
                                store_df = True)
# Out:
# Retrieving weather data for Barasat
#
#
# Currently retrieving data for Barasat: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.518132
# Currently retrieving data for Barasat: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:02.513825
# Currently retrieving data for Barasat: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.696336
# Currently retrieving data for Barasat: from 2020-04-01 to 2020-04-08
# Time elapsed (hh:mm:ss.ms) 0:00:04.364277
#
#
# export Barasat completed!
#
#
#
#
# Retrieving weather data for Bagalkot
#
#
# Currently retrieving data for Bagalkot: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.279020
# Currently retrieving data for Bagalkot: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:02.356591
# Currently retrieving data for Bagalkot: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.385924
# ...

# %%
# For alphabet C
location_list_C = ['Chandigarh', 'Charki+Dadri', 'Chengalpattu', 'Chennai', 'Chhindwara', 'Chitradurga', 'Chittoor', 'Chota+Udaipur', 'Churu', 'Coimbatore', 'Cuddalore', 'Cuttack']
hist_weather_data_C = retrieve_hist_data(api_key,
                                location_list_C,
                                start_date,
                                end_date,
                                frequency,
                                location_label = False,
                                export_csv = True,
                                store_df = True)
# Out:
# Retrieving weather data for Chandigarh
#
#
# Currently retrieving data for Chandigarh: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.034766
# Currently retrieving data for Chandigarh: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:03.591611
# Currently retrieving data for Chandigarh: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:06.358086
# Currently retrieving data for Chandigarh: from 2020-04-01 to 2020-04-08
# Time elapsed (hh:mm:ss.ms) 0:00:07.023806
#
#
# export Chandigarh completed!
#
#
#
#
# Retrieving weather data for Charki+Dadri
#
#
# Currently retrieving data for Charki+Dadri: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.428709
# Currently retrieving data for Charki+Dadri: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:02.669310
# Currently retrieving data for Charki+Dadri: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:04.429303
# ...

# %%
# For alphabet D
location_list_D = ['Dakshina+Kannada', 'Dausa', 'Dehradun', 'Dharwad', 'Dhaulpur', 'Dhubri', 'Dindigul', 'Dungarpur', 'Durg']
# location_list_D = ['Durg']
hist_weather_data_D = retrieve_hist_data(api_key,
                                location_list_D,
                                start_date,
                                end_date,
                                frequency,
                                location_label = False,
                                export_csv = True,
                                store_df = True)
# Out:
# Retrieving weather data for Dakshina+Kannada
#
#
# Currently retrieving data for Dakshina+Kannada: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.820373
# Currently retrieving data for Dakshina+Kannada: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:03.533255
# Currently retrieving data for Dakshina+Kannada: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:05.075088
# Currently retrieving data for Dakshina+Kannada: from 2020-04-01 to 2020-04-08
# Time elapsed (hh:mm:ss.ms) 0:00:06.046565
#
#
# export Dakshina+Kannada completed!
#
#
#
#
# Retrieving weather data for Dausa
#
#
# Currently retrieving data for Dausa: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.472252
# Currently retrieving data for Dausa: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:02.991437
# Currently retrieving data for Dausa: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:04.623493
# ...

# %%
# For alphabet E
location_list_E = ['East+Delhi', 'East+Godavari', 'Ernakulam', 'Erode']
hist_weather_data_E = retrieve_hist_data(api_key,
                                location_list_E,
                                start_date,
                                end_date,
                                frequency,
                                location_label = False,
                                export_csv = True,
                                store_df = True)
# Out:
# Retrieving weather data for East+Delhi
#
#
# Currently retrieving data for East+Delhi: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.249007
# Currently retrieving data for East+Delhi: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:02.792625
# Currently retrieving data for East+Delhi: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:04.099195
# Currently retrieving data for East+Delhi: from 2020-04-01 to 2020-04-08
# Time elapsed (hh:mm:ss.ms) 0:00:04.935549
#
#
# export East+Delhi completed!
#
#
#
#
# Retrieving weather data for East+Godavari
#
#
# Currently retrieving data for East+Godavari: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.338976
# Currently retrieving data for East+Godavari: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:02.763434
# Currently retrieving data for East+Godavari: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:04.459519
# ...

# %%
# For alphabet F
location_list_A = ['Faridabad', 'Faridkot', 'Fatehgarh+Sahib', 'Firozabad']
hist_weather_data_A = retrieve_hist_data(api_key,
                                location_list_A,
                                start_date,
                                end_date,
                                frequency,
                                location_label = False,
                                export_csv = True,
                                store_df = True)
# Out:
# Retrieving weather data for Faridabad
#
#
# Currently retrieving data for Faridabad: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.878489
# Currently retrieving data for Faridabad: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:04.568735
# Currently retrieving data for Faridabad: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:05.979860
# Currently retrieving data for Faridabad: from 2020-04-01 to 2020-04-08
# Time elapsed (hh:mm:ss.ms) 0:00:06.803222
#
#
# export Faridabad completed!
#
#
#
#
# Retrieving weather data for Faridkot
#
#
# Currently retrieving data for Faridkot: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.249163
# Currently retrieving data for Faridkot: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:02.906533
# Currently retrieving data for Faridkot: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:04.590983
# ...

# %%
# For alphabet G
# location_list_A = ['Gadag', 'Gandhinagar', 'Gautam+Buddh+Nagar', 'Gaya', 'Ghaziabad', 'Ghazipur', 'Gir', 'Goalpara', 'Golaghat', 'Gomati' 'Gondia', 'Gopalganj', 'Guntur', 'Gurgaon', 'Gwalior']
location_list_A = ['Golaghat']

hist_weather_data_A = retrieve_hist_data(api_key,
                                location_list_A,
                                start_date,
                                end_date,
                                frequency,
                                location_label = False,
                                export_csv = True,
                                store_df = True)
# Out:
# Retrieving weather data for Golaghat
#
#
# Currently retrieving data for Golaghat: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.351124
# Currently retrieving data for Golaghat: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:02.449718
# Currently retrieving data for Golaghat: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.594179
# Currently retrieving data for Golaghat: from 2020-04-01 to 2020-04-08
# Time elapsed (hh:mm:ss.ms) 0:00:04.173491
#
#
# export Golaghat completed!

# %%
# For alphabet H
location_list_H = ['Hailakandi', 'Hapur', 'Hardoi', 'Haridwar', 'Hathras', 'Hazaribagh', 'Hingoli', 'Hisar', 'Hooghly', 'Hoshiarpur', 'Howrah', 'Hyderabad']
hist_weather_data_H = retrieve_hist_data(api_key,
                                location_list_H,
                                start_date,
                                end_date,
                                frequency,
                                location_label = False,
                                export_csv = True,
                                store_df = True)
# Out:
# Retrieving weather data for Hailakandi
#
#
# Currently retrieving data for Hailakandi: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:07.967825
# Currently retrieving data for Hailakandi: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:09.928695
# Currently retrieving data for Hailakandi: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:12.227185
# Currently retrieving data for Hailakandi: from 2020-04-01 to 2020-04-08
# Time elapsed (hh:mm:ss.ms) 0:00:13.105463
#
#
# export Hailakandi completed!
#
#
#
#
# Retrieving weather data for Hapur
#
#
# Currently retrieving data for Hapur: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.840143
# Currently retrieving data for Hapur: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:03.480396
# Currently retrieving data for Hapur: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:05.264920
# ...

# %%
# For alphabet I
location_list_I = ['Idukki', 'Imphal', 'Indore']
hist_weather_data_I = retrieve_hist_data(api_key,
                                location_list_I,
                                start_date,
                                end_date,
                                frequency,
                                location_label = False,
                                export_csv = True,
                                store_df = True)
# Out:
# Retrieving weather data for Idukki
#
#
# Currently retrieving data for Idukki: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.536977
# Currently retrieving data for Idukki: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:02.634743
# Currently retrieving data for Idukki: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.717624
# Currently retrieving data for Idukki: from 2020-04-01 to 2020-04-08
# Time elapsed (hh:mm:ss.ms) 0:00:04.371967
#
#
# export Idukki completed!
#
#
#
#
# Retrieving weather data for Imphal
#
#
# Currently retrieving data for Imphal: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.323956
# Currently retrieving data for Imphal: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:02.451153
# Currently retrieving data for Imphal: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.970190
# Currently retrieving data for Imphal: from 2020-04-01 to 2020-04-08
# ...

# %%
# For alphabet J
# location_list_J = ['Jabalpur', 'Jagtial', 'Jaipur', 'Jaisalmer', 'Jajapur', 'Jalandhar', 'Jalgaon', 'Jalna', 'Jammu', 'Jamnagar', 'Jaunpur', 'Jhunjhunu', 'Jind', 'Jodhpur', 'Gadwal', 'Jorhat']
location_list_J = ['Jagtial']

hist_weather_data_J = retrieve_hist_data(api_key,
                                location_list_J,
                                start_date,
                                end_date,
                                frequency,
                                location_label = False,
                                export_csv = True,
                                store_df = True)
# Out:
# Retrieving weather data for Jagtial
#
#
# Currently retrieving data for Jagtial: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.620953
# Currently retrieving data for Jagtial: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:02.804802
# Currently retrieving data for Jagtial: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:04.008618
# Currently retrieving data for Jagtial: from 2020-04-01 to 2020-04-08
# Time elapsed (hh:mm:ss.ms) 0:00:04.525117
#
#
# export Jagtial completed!

# %%
# For alphabet K
# location_list_K = ['Kutch', 'Kaithal', 'Kadapa', 'Kalaburagi', 'Kalahandi', 'Kalimpong', 'Kallakurichi', 'Kamrup', 'Kanchipuram', 'Kangra', 'Kanyakumari', 'Kannur', 'Kanpur', 'Kapurthala', 'Karauli', 'Kargil', 'Karimnagar', 'Karnal', 'Karur', 'Kasaragod', 'Kashmir', 'Kaushambi', 'Kendrapara', 'Khargone', 'Kheri', 'Khordha', 'Kodagu', 'Kolhapur', 'Kolkata', 'Kollam', 'Korba', 'Kota', 'Kottayam', 'Kozhikode', 'Krishna', 'Kurnool']
location_list_K = ['Kendrapara', 'Khargone', 'Kheri', 'Khordha', 'Kodagu', 'Kolhapur', 'Kolkata', 'Kollam', 'Korba', 'Kota', 'Kottayam', 'Kozhikode', 'Krishna', 'Kurnool']

hist_weather_data_K = retrieve_hist_data(api_key,
                                location_list_K,
                                start_date,
                                end_date,
                                frequency,
                                location_label = False,
                                export_csv = True,
                                store_df = True)
# Out:
# Retrieving weather data for Kendrapara
#
#
# Currently retrieving data for Kendrapara: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.116304
# Currently retrieving data for Kendrapara: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:03.781370
# Currently retrieving data for Kendrapara: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:06.002087
# Currently retrieving data for Kendrapara: from 2020-04-01 to 2020-04-08
# Time elapsed (hh:mm:ss.ms) 0:00:06.756993
#
#
# export Kendrapara completed!
#
#
#
#
# Retrieving weather data for Khargone
#
#
# Currently retrieving data for Khargone: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.797864
# Currently retrieving data for Khargone: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:03.198797
# Currently retrieving data for Khargone: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:04.934182
# ...

# %%
# For alphabet L
location_list_L = ['Lakhimpur', 'Lakhisarai', 'Latur', 'Leh', 'Lohit', 'Lucknow', 'Ludhiana']
hist_weather_data_L = retrieve_hist_data(api_key,
                                location_list_L,
                                start_date,
                                end_date,
                                frequency,
                                location_label = False,
                                export_csv = True,
                                store_df = True)
# Out:
# Retrieving weather data for Lakhimpur
#
#
# Currently retrieving data for Lakhimpur: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.546862
# Currently retrieving data for Lakhimpur: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:03.048503
# Currently retrieving data for Lakhimpur: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:04.516358
# Currently retrieving data for Lakhimpur: from 2020-04-01 to 2020-04-08
# Time elapsed (hh:mm:ss.ms) 0:00:05.280157
#
#
# export Lakhimpur completed!
#
#
#
#
# Retrieving weather data for Lakhisarai
#
#
# Currently retrieving data for Lakhisarai: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.641611
# Currently retrieving data for Lakhisarai: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:03.298178
# Currently retrieving data for Lakhisarai: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:04.773245
# ...

# %%
# For alphabet M
# location_list_M = ['Madurai', 'Mahbubnagar', 'Mahe', 'Mehsana', 'Maharajganj', 'Malappuram', 'Mandya', 'Mansa', 'Medchal', 'Midnapore', 'Meerut', 'Mirzapur', 'Moga', 'Moradabad', 'Morbi', 'Morena', 'Marigaon', 'Mumbai', 'Munger', 'Mysuru']
location_list_M = ['Mahbubnagar']

hist_weather_data_M = retrieve_hist_data(api_key,
                                location_list_M,
                                start_date,
                                end_date,
                                frequency,
                                location_label = False,
                                export_csv = True,
                                store_df = True)
# Out:
# Retrieving weather data for Marigaon
#
#
# Currently retrieving data for Marigaon: from 2020-01-01 to 2020-01-31
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-81-5fdd6580907e> in <module>
#      10                                 location_label = False,
#      11                                 export_csv = True,
# ---> 12                                 store_df = True)
#
# G:\Anaconda\envs\Sarthak\lib\site-packages\wwo_hist\__init__.py in retrieve_hist_data(api_key, location_list, start_date, end_date, frequency, location_label, export_csv, store_df)
#     104     for location in location_list:
#     105         print('\n\nRetrieving weather data for '+location+'\n\n')
# --> 106         df_this_city = retrieve_this_location(api_key,location,start_date,end_date,frequency)
#     107
#     108         if (location_label == True):
#
# ...

# %%
# For alphabet N
#North 24 Parganas -> Barasat
#North and Middle Andaman -> Mayabunder
# location_list_N = ['Nadia', 'Nagapattinam', 'Nagpur', 'Nainital', 'Nalanda', 'Nalbari', 'Namakkal', 'Nashik', 'New+Delhi', 'Barasat', 'Mayabunder', 'North+Delhi', 'North+East+Delhi', 'North+Goa', 'North+West+Delhi']
location_list_N = ['Nalanda', 'Nalbari', 'Namakkal', 'New+Delhi', 'Nirmal', 'Nizamabad', 'North+Delhi', 'North+East+Delhi', 'North+Goa', 'North+West+Delhi', 'Nuh']
# location_list_N = ['North+West+Delhi']
hist_weather_data_N = retrieve_hist_data(api_key,
                                location_list_N,
                                start_date,
                                end_date,
                                frequency,
                                location_label = False,
                                export_csv = True,
                                store_df = True)
# Out:
# Retrieving weather data for Nalanda
#
#
# Currently retrieving data for Nalanda: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.214555
# Currently retrieving data for Nalanda: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:02.565138
# Currently retrieving data for Nalanda: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.723817
# Currently retrieving data for Nalanda: from 2020-04-01 to 2020-04-08
# Time elapsed (hh:mm:ss.ms) 0:00:04.290811
#
#
# export Nalanda completed!
#
#
#
#
# Retrieving weather data for Nalbari
#
#
# Currently retrieving data for Nalbari: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.265576
# Currently retrieving data for Nalbari: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:02.639647
# Currently retrieving data for Nalbari: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.916714
# Currently retrieving data for Nalbari: from 2020-04-01 to 2020-04-08
# ...

# %%
# For alphabet O
location_list_O = ['Osmanabad']
hist_weather_data_O = retrieve_hist_data(api_key,
                                location_list_O,
                                start_date,
                                end_date,
                                frequency,
                                location_label = False,
                                export_csv = True,
                                store_df = True)
# Out:
# Retrieving weather data for Osmanabad
#
#
# Currently retrieving data for Osmanabad: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.251249
# Currently retrieving data for Osmanabad: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:02.295305
# Currently retrieving data for Osmanabad: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.716329
# Currently retrieving data for Osmanabad: from 2020-04-01 to 2020-04-08
# Time elapsed (hh:mm:ss.ms) 0:00:04.199134
#
#
# export Osmanabad completed!

# %%
# For alphabet P
#Panch Mahal -> Godhra
# location_list_P = ['Palakkad', 'Pali', 'Palwal', 'Godhra', 'Panipat', 'Patan', 'Pathanamthitta', 'Pathankot', 'Patiala', 'Patna', 'Pauri', 'Pilibhit', 'Porbandar', 'Pratapgarh', 'Prayagraj', 'Puducherry', 'Pune', 'Puri']
location_list_P = ['Puducherry', 'Pune', 'Puri']

hist_weather_data_P = retrieve_hist_data(api_key,
                                location_list_P,
                                start_date,
                                end_date,
                                frequency,
                                location_label = False,
                                export_csv = True,
                                store_df = True)
# Out:
# Retrieving weather data for Puducherry
#
#
# Currently retrieving data for Puducherry: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.065198
# Currently retrieving data for Puducherry: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:03.374396
# Currently retrieving data for Puducherry: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:05.236977
# Currently retrieving data for Puducherry: from 2020-04-01 to 2020-04-08
# Time elapsed (hh:mm:ss.ms) 0:00:06.066195
#
#
# export Puducherry completed!
#
#
#
#
# Retrieving weather data for Pune
#
#
# Currently retrieving data for Pune: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.933234
# Currently retrieving data for Pune: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:03.114319
# Currently retrieving data for Pune: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:04.737409
# ...

# %%
# For alphabet R
#Ranga Reddy -> Shamsabad
# location_list_R = ['Rae+Bareli', 'Raipur', 'Rajkot', 'Rajnandgaon', 'Rajouri', 'Ranchi', 'Shamshabad', 'Ranipet', 'Ratnagiri', 'Rohtak', 'Rupnagar']
location_list_R = ['Rajouri', 'Ranchi', 'Shamshabad', 'Ranipet', 'Ratnagiri', 'Rohtak', 'Rupnagar']

hist_weather_data_R = retrieve_hist_data(api_key,
                                location_list_R,
                                start_date,
                                end_date,
                                frequency,
                                location_label = False,
                                export_csv = True,
                                store_df = True)
# Out:
# Retrieving weather data for Rajouri
#
#
# Currently retrieving data for Rajouri: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.569341
# Currently retrieving data for Rajouri: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:05.934979
# Currently retrieving data for Rajouri: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:14.630593
# Currently retrieving data for Rajouri: from 2020-04-01 to 2020-04-08
# Time elapsed (hh:mm:ss.ms) 0:00:17.313201
#
#
# export Rajouri completed!
#
#
#
#
# Retrieving weather data for Ranchi
#
#
# Currently retrieving data for Ranchi: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:06.034787
# Currently retrieving data for Ranchi: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:11.814268
# Currently retrieving data for Ranchi: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:16.052839
# Currently retrieving data for Ranchi: from 2020-04-01 to 2020-04-08
# ...

# %%
# For alphabet S
#SAS Nagar -> Mohali
#SPS Nellore -> Nellore
#Sabar Kantha -> Himatnagar
#Shaheed Bhagat Singh Nagar -> Nawanshahr
#South 24 Parganas -> Alipore
#South Andaman -> Port Blair
# South Salmara Mancachar -> Hatsingimari
# location_list_S = ['Mohali', 'Nellore', 'Himatnagar', 'Saharanpur', 'Salem', 'Sangareddy', 'Sangli', 'Saran', 'Satara', 'Satna', 'Nawanshahr', 'Shahjahanpur', 'Shamli', 'Sheopur', 'Shivpuri', 'Shupiyan', 'Sikar', 'Sindhudurg', 'Sirsa', 'Sitapur', 'Sivaganga', 'Siwan', 'Sonipat', 'Alipore', 'Port+Blair', 'South+Delhi', 'Hatsingimari', 'South+West+Delhi', 'Srinagar', 'Surat', 'Suryapet']
location_list_S = ['South+West+Delhi', 'Srinagar', 'Surat', 'Suryapet']

hist_weather_data_S = retrieve_hist_data(api_key,
                                location_list_S,
                                start_date,
                                end_date,
                                frequency,
                                location_label = False,
                                export_csv = True,
                                store_df = True)
# Out:
# Retrieving weather data for South+West+Delhi
#
#
# Currently retrieving data for South+West+Delhi: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.156495
# Currently retrieving data for South+West+Delhi: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:02.199640
# Currently retrieving data for South+West+Delhi: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.481411
# Currently retrieving data for South+West+Delhi: from 2020-04-01 to 2020-04-08
# Time elapsed (hh:mm:ss.ms) 0:00:04.160852
#
#
# export South+West+Delhi completed!
#
#
#
#
# Retrieving weather data for Srinagar
#
#
# Currently retrieving data for Srinagar: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.415728
# Currently retrieving data for Srinagar: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:02.758628
# Currently retrieving data for Srinagar: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.944216
# ...

# %%
# For alphabet T
# The Nilgiris -> Udhagamandalam
# location_list_T = ['Thane', 'Thanjavur', 'Udhagamandalam', 'Theni', 'Thiruvallur', 'Thiruvananthapuram', 'Thiruvarur', 'Thoothukudi', 'Thrissur', 'Tiruchirappalli', 'Tirunelveli', 'Tirupathur', 'Tiruppur', 'Tiruvannamalai', 'Tonk', 'Tumakuru']
location_list_T = ['Thane', 'Thanjavur', 'Udhagamandalam', 'Theni', 'Thiruvananthapuram', 'Thiruvarur', 'Thoothukudi', 'Thrissur', 'Tiruchirappalli', 'Tirunelveli', 'Tiruppur', 'Tiruvannamalai', 'Tonk', 'Tumakuru']

hist_weather_data_T = retrieve_hist_data(api_key,
                                location_list_T,
                                start_date,
                                end_date,
                                frequency,
                                location_label = False,
                                export_csv = True,
                                store_df = True)
# Out:
# Retrieving weather data for Thane
#
#
# Currently retrieving data for Thane: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.405470
# Currently retrieving data for Thane: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:02.600041
# Currently retrieving data for Thane: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.797723
# Currently retrieving data for Thane: from 2020-04-01 to 2020-04-08
# Time elapsed (hh:mm:ss.ms) 0:00:04.271225
#
#
# export Thane completed!
#
#
#
#
# Retrieving weather data for Thanjavur
#
#
# Currently retrieving data for Thanjavur: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.561486
# Currently retrieving data for Thanjavur: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:02.595720
# Currently retrieving data for Thanjavur: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.646480
# Currently retrieving data for Thanjavur: from 2020-04-01 to 2020-04-08
# ...

# %%
# For alphabet U
# Udham Singh Nagar -> Rudrapur
# Uttara Kannada -> Bhatkal 
location_list_U = ['Rudrapur', 'Udhampur', 'Udupi', 'Ujjain', 'Una', 'Bhatkal']
hist_weather_data_U = retrieve_hist_data(api_key,
                                location_list_U,
                                start_date,
                                end_date,
                                frequency,
                                location_label = False,
                                export_csv = True,
                                store_df = True)
# Out:
# Retrieving weather data for Rudrapur
#
#
# Currently retrieving data for Rudrapur: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.103605
# Currently retrieving data for Rudrapur: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:02.236422
# Currently retrieving data for Rudrapur: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.401091
# Currently retrieving data for Rudrapur: from 2020-04-01 to 2020-04-08
# Time elapsed (hh:mm:ss.ms) 0:00:04.308874
#
#
# export Rudrapur completed!
#
#
#
#
# Retrieving weather data for Udhampur
#
#
# Currently retrieving data for Udhampur: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.292351
# Currently retrieving data for Udhampur: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:02.487642
# Currently retrieving data for Udhampur: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.642216
# ...

# %%
# For alphabet V 

# location_list_V = ['Vadodara', 'Varanasi', 'Vellore', 'Vidisha', 'Vikarabad', 'Viluppuram', 'Virudhunagar', 'Visakhapatnam']
location_list_V = ['Vadodara', 'Varanasi', 'Vellore', 'Vidisha', 'Vikarabad', 'Viluppuram', 'Visakhapatnam']

hist_weather_data_V = retrieve_hist_data(api_key,
                                location_list_V,
                                start_date,
                                end_date,
                                frequency,
                                location_label = False,
                                export_csv = True,
                                store_df = True)
# Out:
# Retrieving weather data for Vadodara
#
#
# Currently retrieving data for Vadodara: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.092795
# Currently retrieving data for Vadodara: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:02.163461
# Currently retrieving data for Vadodara: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.296553
# Currently retrieving data for Vadodara: from 2020-04-01 to 2020-04-08
# Time elapsed (hh:mm:ss.ms) 0:00:03.809831
#
#
# export Vadodara completed!
#
#
#
#
# Retrieving weather data for Varanasi
#
#
# Currently retrieving data for Varanasi: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.136586
# Currently retrieving data for Varanasi: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:02.244481
# Currently retrieving data for Varanasi: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.334673
# ...

# %%
# For alphabet W 
# location_list_W = ['Washim', 'Wayanad', 'West+Delhi', 'West+Godavari']
location_list_W = ['Washim', 'West+Delhi', 'West+Godavari']

hist_weather_data_W = retrieve_hist_data(api_key,
                                location_list_W,
                                start_date,
                                end_date,
                                frequency,
                                location_label = False,
                                export_csv = True,
                                store_df = True)
# Out:
# Retrieving weather data for Washim
#
#
# Currently retrieving data for Washim: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.333022
# Currently retrieving data for Washim: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:02.356748
# Currently retrieving data for Washim: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.394683
# Currently retrieving data for Washim: from 2020-04-01 to 2020-04-08
# Time elapsed (hh:mm:ss.ms) 0:00:03.856743
#
#
# export Washim completed!
#
#
#
#
# Retrieving weather data for West+Delhi
#
#
# Currently retrieving data for West+Delhi: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.216615
# Currently retrieving data for West+Delhi: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:02.488571
# Currently retrieving data for West+Delhi: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.719465
# ...

# %%
# For alphabet Y 
#YSR -> Kadapa
location_list_Y = ['Kadapa', 'Yavatmal']
hist_weather_data_Y = retrieve_hist_data(api_key,
                                location_list_Y,
                                start_date,
                                end_date,
                                frequency,
                                location_label = False,
                                export_csv = True,
                                store_df = True)
# Out:
# Retrieving weather data for Kadapa
#
#
# Currently retrieving data for Kadapa: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.323372
# Currently retrieving data for Kadapa: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:02.409052
# Currently retrieving data for Kadapa: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.659357
# Currently retrieving data for Kadapa: from 2020-04-01 to 2020-04-08
# Time elapsed (hh:mm:ss.ms) 0:00:04.188864
#
#
# export Kadapa completed!
#
#
#
#
# Retrieving weather data for Yavatmal
#
#
# Currently retrieving data for Yavatmal: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.138457
# Currently retrieving data for Yavatmal: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:02.171231
# Currently retrieving data for Yavatmal: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.262587
# Currently retrieving data for Yavatmal: from 2020-04-01 to 2020-04-08
# ...

# %%
#Trying for the citites which are left
# locatoin_list_left=['Bandipore', 'Cachar', 'Chikkaballapur', 'Davanagere', 'Kalaburagi', 'Kalimpong', 'Kamrup', 'Nashik', 'Mayabunder', 'Panchkula', 'Prakasam', 'Ramnathpuram', 'Thiruvallur', 'Tirupathur', 'Virudhunagar', 'Wayanad']
lat_long = ['34.5052,74.6869', '24.7821,92.8577', '13.4355,77.7315', '14.4644,75.9218', '17.3297,76.8343', '27.0594,88.4695', '26.3161,91.5984', '19.9975,73.7898', '12.9131,92.8977', '30.6942,76.8605', '15.3485,79.5603', '9.3639,78.8395', '13.2544,80.0088', '12.4950,78.5678', '9.5680,77.9624', '11.6854,76.1320']

hist_weather_data_lat_long = retrieve_hist_data(api_key,
                                lat_long,
                                start_date,
                                end_date,
                                frequency,
                                location_label = False,
                                export_csv = True,
                                store_df = True)
# Out:
# Retrieving weather data for 34.5052,74.6869
#
#
# Currently retrieving data for 34.5052,74.6869: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.361139
# Currently retrieving data for 34.5052,74.6869: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:02.358477
# Currently retrieving data for 34.5052,74.6869: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.419549
# Currently retrieving data for 34.5052,74.6869: from 2020-04-01 to 2020-04-08
# Time elapsed (hh:mm:ss.ms) 0:00:03.965863
#
#
# export 34.5052,74.6869 completed!
#
#
#
#
# Retrieving weather data for 24.7821,92.8577
#
#
# Currently retrieving data for 24.7821,92.8577: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.381011
# Currently retrieving data for 24.7821,92.8577: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:02.392013
# Currently retrieving data for 24.7821,92.8577: from 2020-03-01 to 2020-03-31
# ...

# %%
# New towns with lat long
location_list2 = ['Kalahandi', 'Kallakurichi', 'Kaushambi', 'Morigaon', 'Nainital', 'Prayagraj', 'Rajnandgaon', 'Sangareddy', 'Sindhudurg', 'Hatsingimari']
lat_long2 = ['19.9137,83.1649', '11.7384,78.9639', '25.5065,81.4279', '26.2529,92.3370', '29.3919,79.4542', '25.4358,81.8463', '21.0972,81.0338', '17.6140,78.0816', '16.3492,73.5594', '25.7131,89.8996']
hist_weather_data_lat_long2 = retrieve_hist_data(api_key,
                                lat_long2,
                                start_date,
                                end_date,
                                frequency,
                                location_label = False,
                                export_csv = True,
                                store_df = True)
# Out:
# Retrieving weather data for 19.9137,83.1649
#
#
# Currently retrieving data for 19.9137,83.1649: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.556980
# Currently retrieving data for 19.9137,83.1649: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:02.529219
# Currently retrieving data for 19.9137,83.1649: from 2020-03-01 to 2020-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.805105
# Currently retrieving data for 19.9137,83.1649: from 2020-04-01 to 2020-04-08
# Time elapsed (hh:mm:ss.ms) 0:00:04.370631
#
#
# export 19.9137,83.1649 completed!
#
#
#
#
# Retrieving weather data for 11.7384,78.9639
#
#
# Currently retrieving data for 11.7384,78.9639: from 2020-01-01 to 2020-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.158491
# Currently retrieving data for 11.7384,78.9639: from 2020-02-01 to 2020-02-29
# Time elapsed (hh:mm:ss.ms) 0:00:02.586937
# Currently retrieving data for 11.7384,78.9639: from 2020-03-01 to 2020-03-31
# ...
